# %% [markdown]
# <h1> <font color = 'blue'><center> CVEN-5306: Computer Aided Design </center></font></h1>

# %% [markdown]
# <h3> <font color = 'green'><center>Md Washemuzzaman Lajuk (L20606192) </center></font></h3>

# %% [markdown]
# <h4> <font color = 'black'><left>Problem Statement</left></font></h4>

# %% [markdown]
# Read the 'SCS_dimensionless_UH.csv' file in '/Users/washemuzzamanlajuk/Desktop/Fall 2025/CAD/

# %%
#Load the Libraries
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
#Set my working directory
path = '/Users/washemuzzamanlajuk/Desktop/Fall 2025/CAD/In Class-1'
os.chdir(path)

# %%
#Read the file
fname = 'SCS_dimensionless_UH.csv'
a = pd.read_csv(fname)

# %%
#Make sure it worked as a
a.head()
# Out:
#    t/Tp  Q/Qp
# 0   0.0  0.00
# 1   0.1  0.03
# 2   0.2  0.10
# 3   0.3  0.19
# 4   0.4  0.31

# %%
plt.plot(a["t/Tp"], a["Q/Qp"], 'b-')
plt.xlabel('Dimensionless Time (t/Tp)')
plt.ylabel('Dimensionless Unit Hydrograph (Q/Qp)')
plt.grid()
plt.title('SCS Dimensionless Unit Hydrograph')
plt.show()
